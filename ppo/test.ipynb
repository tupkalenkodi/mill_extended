# %%
from ray.rllib.algorithms.ppo import PPOConfig
from ray.rllib.connectors.env_to_module import FlattenObservations

# Configure the algorithm.
config = (
    PPOConfig()
    .environment("Taxi-v3")
    .env_runners(
        num_env_runners=2,
        # Observations are discrete (ints) -> We need to flatten (one-hot) them.
        env_to_module_connector=lambda env: FlattenObservations(),
    )
    .evaluation(evaluation_num_env_runners=1)
)
# Out:
# 2026-01-03 17:14:37,201	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2026-01-03 17:14:43,926	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %%
from pprint import pprint

# Build the algorithm.
algo = config.build_algo()

# Train it for 5 iterations ...
for _ in range(5):
    pprint(algo.train())
# Out:
# 2026-01-03 17:14:57,443	WARNING algorithm_config.py:5006 -- You have specified 1 evaluation workers, but your `evaluation_interval` is 0 or None! Therefore, evaluation doesn't occur automatically with each call to `Algorithm.train()`. Instead, you have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# 2026-01-03 17:14:57,447	WARNING algorithm_config.py:5118 -- You are running PPO on the new API stack! This is the new default behavior for this algorithm. If you don't want to use the new API stack, set `config.api_stack(enable_rl_module_and_learner=False,enable_env_runner_and_connector_v2=False)`. For a detailed migration guide, see here: https://docs.ray.io/en/master/rllib/new-api-stack-migration-guide.html
# /home/cubic/PROJECTS/mill_copy/.venv/lib/python3.12/site-packages/ray/rllib/algorithms/algorithm.py:527: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/cubic/PROJECTS/mill_copy/.venv/lib/python3.12/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/cubic/PROJECTS/mill_copy/.venv/lib/python3.12/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/cubic/PROJECTS/mill_copy/.venv/lib/python3.12/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2026-01-03 17:15:08,631	INFO worker.py:2007 -- Started a local Ray instance.
# /home/cubic/PROJECTS/mill_copy/.venv/lib/python3.12/site-packages/ray/_private/worker.py:2046: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# [2026-01-03 17:15:27,773 E 10281 10281] core_worker.cc:2223: Actor with class name: 'SingleAgentEnvRunner' and ID: '1a69c7ccaacd92162bc98b4901000000' has constructor arguments in the object store and max_restarts > 0. If the arguments in the object store go out of scope or are lost, the actor restart will fail. See https://github.com/ray-project/ray/issues/53727 for more details.
# (pid=gcs_server) [2026-01-03 17:15:28,283 E 10392 10392] (gcs_server) gcs_server.cc:303: Failed to establish connection to the event+metrics exporter agent. Events and metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-01-03 17:15:38,214 E 10515 10515] (raylet) main.cc:1032: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# [2026-01-03 17:15:57,183 E 10281 10559] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (raylet) [2026-01-03 17:16:07,683 E 10515 10515] (raylet) node_manager.cc:3256: 13 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 31d85d9a702a7d45c54fa9853ebb44f04fcd651790f16c9c442ab7b8, IP: 172.20.10.3) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 172.20.10.3`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (SingleAgentEnvRunner pid=11148) 2026-01-03 17:16:17,316	ERROR algorithm_config.py:1037 -- Your `config.env_to_module_connector` function seems to have a wrong or outdated signature! It should be: `def myfunc(env, spaces, device): ...`, where any of these arguments are optional and may be None.
# (SingleAgentEnvRunner pid=11148) `env` is the (vectorized) gym env.
# (SingleAgentEnvRunner pid=11148) `spaces` is a dict of structure `{'__env__': ([vectorized env obs. space, vectorized env act. space]),'__env_single__': ([env obs. space, env act. space])}`.
# (SingleAgentEnvRunner pid=11148) `device` is a (torch) device.
# (SingleAgentEnvRunner pid=11148)
# (SingleAgentEnvRunner pid=11148) DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
# (SingleAgentEnvRunner pid=11224)
# 2026-01-03 17:16:21,435	ERROR algorithm_config.py:1037 -- Your `config.env_to_module_connector` function seems to have a wrong or outdated signature! It should be: `def myfunc(env, spaces, device): ...`, where any of these arguments are optional and may be None.
# `env` is the (vectorized) gym env.
# `spaces` is a dict of structure `{'__env__': ([vectorized env obs. space, vectorized env act. space]),'__env_single__': ([env obs. space, env act. space])}`.
# `device` is a (torch) device.
#
# 2026-01-03 17:16:22,065	WARNING rl_module.py:459 -- DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
# 2026-01-03 17:16:22,163	WARNING algorithm_config.py:5006 -- You have specified 1 evaluation workers, but your `evaluation_interval` is 0 or None! Therefore, evaluation doesn't occur automatically with each call to `Algorithm.train()`. Instead, you have to call `Algorithm.evaluate()` manually in order to trigger an evaluation run.
# (SingleAgentEnvRunner pid=11148) [2026-01-03 17:16:34,259 E 11148 11179] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# (SingleAgentEnvRunner pid=11224) 2026-01-03 17:16:21,039	ERROR algorithm_config.py:1037 -- Your `config.env_to_module_connector` function seems to have a wrong or outdated signature! It should be: `def myfunc(env, spaces, device): ...`, where any of these arguments are optional and may be None.
# (SingleAgentEnvRunner pid=11224) `env` is the (vectorized) gym env.
# (SingleAgentEnvRunner pid=11224) `spaces` is a dict of structure `{'__env__': ([vectorized env obs. space, vectorized env act. space]),'__env_single__': ([env obs. space, env act. space])}`.
# (SingleAgentEnvRunner pid=11224) `device` is a (torch) device.
# (SingleAgentEnvRunner pid=11224) DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
# (SingleAgentEnvRunner pid=11269) 2026-01-03 17:16:36,533	ERROR algorithm_config.py:1037 -- Your `config.env_to_module_connector` function seems to have a wrong or outdated signature! It should be: `def myfunc(env, spaces, device): ...`, where any of these arguments are optional and may be None.
# (SingleAgentEnvRunner pid=11269) `env` is the (vectorized) gym env.
# (SingleAgentEnvRunner pid=11269) `spaces` is a dict of structure `{'__env__': ([vectorized env obs. space, vectorized env act. space]),'__env_single__': ([env obs. space, env act. space])}`.
# (SingleAgentEnvRunner pid=11269) `device` is a (torch) device.
# (SingleAgentEnvRunner pid=11269)
# (SingleAgentEnvRunner pid=11269) DeprecationWarning: `RLModule(config=[RLModuleConfig object])` has been deprecated. Use `RLModule(observation_space=.., action_space=.., inference_only=.., model_config=.., catalog_class=..)` instead. This will raise an error in the future!
# (SingleAgentEnvRunner pid=11224) [2026-01-03 17:16:42,447 E 11224 11249] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# 2026-01-03 17:16:43,400	INFO trainable.py:161 -- Trainable.setup took 105.853 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2026-01-03 17:16:43,403	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# (SingleAgentEnvRunner pid=11269) [2026-01-03 17:16:57,279 E 11269 11318] core_worker_process.cc:842: Failed to establish connection to the metrics exporter agent. Metrics will not be exported. Exporter agent status: RpcError: Running out of retries to initialize the metrics agent. rpc_code: 14
# {'config': {'_disable_action_flattening': False,
#             '_disable_execution_plan_api': -1,
#             '_disable_initialize_loss_from_dummy_batch': False,
#             '_disable_preprocessor_api': False,
#             '_dont_auto_sync_env_runner_states': False,
#             '_enable_rl_module_api': -1,
#             '_env_to_module_connector': <function <lambda> at 0x764db0583c40>,
#             '_fake_gpus': False,
#             '_is_atari': None,
#             '_is_online': True,
#             '_learner_class': None,
#             '_learner_connector': None,
#             '_model_config': {},
#             '_module_to_env_connector': None,
#             '_per_module_overrides': {},
#             '_prior_exploration_config': {'type': 'StochasticSampling'},
#             '_rl_module_spec': None,
#             '_tf_policy_handles_more_than_one_loss': False,
#             '_torch_grad_scaler_class': None,
#             '_torch_lr_scheduler_classes': None,
#             '_train_batch_size_per_learner': None,
#             '_use_msgpack_checkpoints': False,
#             '_validate_config': True,
#             'action_mask_key': 'action_mask',
#             'action_space': None,
#             'actions_in_input_normalized': False,
#             'add_default_connectors_to_env_to_module_pipeline': True,
#             'add_default_connectors_to_learner_pipeline': True,
#             'add_default_connectors_to_module_to_env_pipeline': True,
#             'algorithm_config_overrides_per_module': {},
#             'always_attach_evaluation_results': -1,
#             'auto_wrap_old_gym_envs': -1,
#             'batch_mode': 'truncate_episodes',
#             'broadcast_env_runner_states': True,
#             'broadcast_offline_eval_runner_states': False,
#             'callbacks': <class 'ray.rllib.callbacks.callbacks.RLlibCallback'>,
#             'callbacks_on_algorithm_init': None,
#             'callbacks_on_checkpoint_loaded': None,
#             'callbacks_on_env_runners_recreated': None,
#             'callbacks_on_environment_created': None,
#             'callbacks_on_episode_created': None,
#             'callbacks_on_episode_end': None,
#             'callbacks_on_episode_start': None,
#             'callbacks_on_episode_step': None,
#             'callbacks_on_evaluate_end': None,
#             'callbacks_on_evaluate_offline_end': None,
#             'callbacks_on_evaluate_offline_start': None,
#             'callbacks_on_evaluate_start': None,
#             'callbacks_on_offline_eval_runners_recreated': None,
#             'callbacks_on_sample_end': None,
#             'callbacks_on_train_result': None,
#             'checkpoint_trainable_policies_only': False,
#             'class': <class 'ray.rllib.algorithms.ppo.ppo.PPOConfig'>,
#             'clip_actions': False,
#             'clip_param': 0.3,
#             'clip_rewards': None,
#             'compress_observations': False,
#             'count_steps_by': 'env_steps',
#             'create_env_on_driver': False,
#             'create_local_env_runner': True,
#             'custom_async_evaluation_function': -1,
#             'custom_eval_function': None,
#             'custom_resources_per_env_runner': {},
#             'custom_resources_per_offline_eval_runner': {},
#             'dataset_num_iters_per_eval_runner': 1,
#             'dataset_num_iters_per_learner': None,
#             'delay_between_env_runner_restarts_s': 60.0,
#             'disable_env_checking': False,
#             'eager_max_retraces': 20,
#             'eager_tracing': True,
#             'enable_async_evaluation': -1,
#             'enable_connectors': -1,
#             'enable_env_runner_and_connector_v2': True,
#             'enable_rl_module_and_learner': True,
#             'enable_tf1_exec_eagerly': False,
#             'entropy_coeff': 0.0,
#             'entropy_coeff_schedule': None,
#             'env': 'Taxi-v3',
#             'env_config': {},
#             'env_runner_cls': None,
#             'env_runner_health_probe_timeout_s': 30.0,
#             'env_runner_restore_timeout_s': 1800.0,
#             'env_task_fn': -1,
#             'episode_lookback_horizon': 1,
#             'episodes_to_numpy': True,
#             'evaluation_auto_duration_max_env_steps_per_sample': 2000,
#             'evaluation_auto_duration_min_env_steps_per_sample': 100,
#             'evaluation_config': None,
#             'evaluation_duration': 10,
#             'evaluation_duration_unit': 'episodes',
#             'evaluation_force_reset_envs_before_iteration': True,
#             'evaluation_interval': None,
#             'evaluation_num_env_runners': 1,
#             'evaluation_parallel_to_training': False,
#             'evaluation_sample_timeout_s': 120.0,
#             'exploration_config': {},
#             'explore': True,
#             'export_native_model_files': False,
#             'extra_python_environs_for_driver': {},
#             'extra_python_environs_for_worker': {},
#             'fake_sampler': False,
#             'framework': 'torch',
#             'gamma': 0.99,
#             'grad_clip': None,
#             'grad_clip_by': 'global_norm',
#             'gym_env_vectorize_mode': 'sync',
#             'ignore_env_runner_failures': False,
#             'ignore_final_observation': False,
#             'ignore_offline_eval_runner_failures': False,
#             'in_evaluation': False,
#             'input': 'sampler',
#             'input_compress_columns': ['obs', 'new_obs'],
#             'input_config': {},
#             'input_filesystem': None,
#             'input_filesystem_kwargs': {},
#             'input_read_batch_size': None,
#             'input_read_episodes': False,
#             'input_read_method': 'read_parquet',
#             'input_read_method_kwargs': {},
#             'input_read_sample_batches': False,
#             'input_read_schema': {},
#             'input_spaces_jsonable': True,
#             'iter_batches_kwargs': {},
#             'keep_per_episode_custom_metrics': False,
#             'kl_coeff': 0.2,
#             'kl_target': 0.01,
#             'lambda': 1.0,
#             'learner_config_dict': {},
#             'local_gpu_idx': 0,
#             'local_tf_session_args': {'inter_op_parallelism_threads': 8,
#                                       'intra_op_parallelism_threads': 8},
#             'log_gradients': False,
#             'log_level': 'WARN',
#             'log_sys_usage': True,
#             'logger_config': None,
#             'logger_creator': None,
#             'lr': 5e-05,
#             'lr_schedule': None,
#             'map_batches_kwargs': {},
#             'materialize_data': False,
#             'materialize_mapped_data': True,
#             'max_num_env_runner_restarts': 1000,
#             'max_num_offline_eval_runner_restarts': 1000,
#             'max_requests_in_flight_per_aggregator_actor': 3,
#             'max_requests_in_flight_per_env_runner': 1,
#             'max_requests_in_flight_per_learner': 3,
#             'max_requests_in_flight_per_offline_eval_runner': 1,
#             'merge_env_runner_states': 'training_only',
#             'metrics_episode_collection_timeout_s': 60.0,
#             'metrics_num_episodes_for_smoothing': 100,
#             'min_sample_timesteps_per_iteration': 0,
#             'min_time_s_per_iteration': None,
#             'min_train_timesteps_per_iteration': 0,
#             'minibatch_size': 128,
#             'model': {'_disable_action_flattening': False,
#                       '_disable_preprocessor_api': False,
#                       '_time_major': False,
#                       '_use_default_native_models': -1,
#                       'always_check_shapes': False,
#                       'attention_dim': 64,
#                       'attention_head_dim': 32,
#                       'attention_init_gru_gate_bias': 2.0,
#                       'attention_memory_inference': 50,
#                       'attention_memory_training': 50,
#                       'attention_num_heads': 1,
#                       'attention_num_transformer_units': 1,
#                       'attention_position_wise_mlp_dim': 32,
#                       'attention_use_n_prev_actions': 0,
#                       'attention_use_n_prev_rewards': 0,
#                       'conv_activation': 'relu',
#                       'conv_bias_initializer': None,
#                       'conv_bias_initializer_config': None,
#                       'conv_filters': None,
#                       'conv_kernel_initializer': None,
#                       'conv_kernel_initializer_config': None,
#                       'conv_transpose_bias_initializer': None,
#                       'conv_transpose_bias_initializer_config': None,
#                       'conv_transpose_kernel_initializer': None,
#                       'conv_transpose_kernel_initializer_config': None,
#                       'custom_action_dist': None,
#                       'custom_model': None,
#                       'custom_model_config': {},
#                       'custom_preprocessor': None,
#                       'dim': 84,
#                       'encoder_latent_dim': None,
#                       'fcnet_activation': 'tanh',
#                       'fcnet_bias_initializer': None,
#                       'fcnet_bias_initializer_config': None,
#                       'fcnet_hiddens': [256, 256],
#                       'fcnet_weights_initializer': None,
#                       'fcnet_weights_initializer_config': None,
#                       'framestack': True,
#                       'free_log_std': False,
#                       'grayscale': False,
#                       'log_std_clip_param': 20.0,
#                       'lstm_bias_initializer': None,
#                       'lstm_bias_initializer_config': None,
#                       'lstm_cell_size': 256,
#                       'lstm_use_prev_action': False,
#                       'lstm_use_prev_action_reward': -1,
#                       'lstm_use_prev_reward': False,
#                       'lstm_weights_initializer': None,
#                       'lstm_weights_initializer_config': None,
#                       'max_seq_len': 20,
#                       'no_final_linear': False,
#                       'post_fcnet_activation': 'relu',
#                       'post_fcnet_bias_initializer': None,
#                       'post_fcnet_bias_initializer_config': None,
#                       'post_fcnet_hiddens': [],
#                       'post_fcnet_weights_initializer': None,
#                       'post_fcnet_weights_initializer_config': None,
#                       'use_attention': False,
#                       'use_lstm': False,
#                       'vf_share_layers': False,
#                       'zero_mean': True},
#             'normalize_actions': True,
#             'num_aggregator_actors_per_learner': 0,
#             'num_consecutive_env_runner_failures_tolerance': 100,
#             'num_cpus_for_main_process': 1,
#             'num_cpus_per_env_runner': 1,
#             'num_cpus_per_learner': 'auto',
#             'num_cpus_per_offline_eval_runner': 1,
#             'num_env_runners': 2,
#             'num_envs_per_env_runner': 1,
#             'num_epochs': 30,
#             'num_gpus': 0,
#             'num_gpus_per_env_runner': 0,
#             'num_gpus_per_learner': 0,
#             'num_gpus_per_offline_eval_runner': 0,
#             'num_learners': 0,
#             'num_offline_eval_runners': 0,
#             'observation_filter': 'NoFilter',
#             'observation_fn': None,
#             'observation_space': None,
#             'off_policy_estimation_methods': {},
#             'offline_data_class': None,
#             'offline_eval_batch_size_per_runner': 256,
#             'offline_eval_rl_module_inference_only': False,
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x764c40ecaca0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'stats_cls_lookup': {'ema': <class 'ray.rllib.utils.metrics.stats.ema.EmaStats'>,
#                                  'item': <class 'ray.rllib.utils.metrics.stats.item.ItemStats'>,
#                                  'item_series': <class 'ray.rllib.utils.metrics.stats.item_series.ItemSeriesStats'>,
#                                  'lifetime_sum': <class 'ray.rllib.utils.metrics.stats.lifetime_sum.LifetimeSumStats'>,
#                                  'max': <class 'ray.rllib.utils.metrics.stats.max.MaxStats'>,
#                                  'mean': <class 'ray.rllib.utils.metrics.stats.mean.MeanStats'>,
#                                  'min': <class 'ray.rllib.utils.metrics.stats.min.MinStats'>,
#                                  'percentiles': <class 'ray.rllib.utils.metrics.stats.percentiles.PercentilesStats'>,
#                                  'sum': <class 'ray.rllib.utils.metrics.stats.sum.SumStats'>},
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2026-01-03_17-17-41',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 2},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': np.float64(-774.6500000000001)},
#                  'env_reset_timer': np.float64(0.0018855105001875927),
#                  'env_step_timer': np.float64(0.0004947827570099324),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.001400858222989862),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(4.4590965158555824e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(1.1164665275547417e-05),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.6930555013129533e-05),
#                                                                        'batch_individual_items': np.float64(0.00017294990836961248),
#                                                                        'flatten_observations': np.float64(0.0003119425194998076),
#                                                                        'numpy_to_tensor': np.float64(0.00024132743482044192)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(131.73765398537716),
#                  'env_to_module_sum_episodes_length_out': np.float64(131.73765398537716),
#                  'episode_duration_sec_mean': np.float64(1.3722963715499419),
#                  'episode_len_max': np.int64(200),
#                  'episode_len_mean': np.float64(200.0),
#                  'episode_len_min': np.int64(200),
#                  'episode_return_max': np.float64(-677.0),
#                  'episode_return_mean': np.float64(-774.6500000000001),
#                  'episode_return_min': np.float64(-875.0),
#                  'module_episode_return_mean': {'default_policy': np.float64(-774.6500000000001)},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.002825908369366758),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.0013427643727479466),
#                                                                        'listify_data_for_vector_env': np.float64(0.00017538406466834165),
#                                                                        'normalize_and_clip_actions': np.float64(0.00017107724470452734),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(1.1015883448982063e-05),
#                                                                        'tensor_to_numpy': np.float64(0.0003606725680405583),
#                                                                        'un_batch_to_individual_items': np.float64(0.00011360159810979659)}}},
#                  'num_agent_steps_sampled': {'default_agent': np.int64(4000)},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 4000.0},
#                  'num_env_steps_sampled': np.int64(4000),
#                  'num_env_steps_sampled_lifetime': 4000.0,
#                  'num_env_steps_sampled_lifetime_throughput': {'throughput_since_last_reduce': 24.42469186546321,
#                                                                'throughput_since_last_restore': 24.424690822815744},
#                  'num_episodes': np.int64(20),
#                  'num_episodes_lifetime': 20.0,
#                  'num_module_steps_sampled': {'default_policy': np.int64(4000)},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 4000.0},
#                  'rlmodule_inference_timer': np.float64(0.000935397783680247),
#                  'sample': np.float64(13.903994709500239),
#                  'weights_seq_no': np.float64(0.0)},
#  'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0},
#  'hostname': 'cubic',
#  'iterations_since_restore': 1,
#  'learners': {'__all_modules__': {'learner_connector': {'connector_pipeline_timer': np.float64(0.7061508159999903),
#                                                         'timers': {'connectors': {'add_columns_from_episodes_to_train_batch': np.float64(0.34226520699985485),
#                                                                                   'add_observations_from_episodes_to_batch': np.float64(0.0010982839999087446),
#                                                                                   'add_one_ts_to_episodes_and_truncate': np.float64(0.02349545399965791),
#                                                                                   'add_states_from_episodes_to_batch': np.float64(3.711199997269432e-05),
#                                                                                   'add_time_dim_to_batch_and_zero_pad': np.float64(7.257100014612661e-05),
#                                                                                   'batch_individual_items': np.float64(0.15411174900009428),
#                                                                                   'general_advantage_estimation': np.float64(0.18230218600001535),
#                                                                                   'numpy_to_tensor': np.float64(0.0009383089995935734)}}},
#                                   'learner_connector_sum_episodes_length_in': np.float64(4000.0),
#                                   'learner_connector_sum_episodes_length_out': np.float64(4020.0),
#                                   'num_env_steps_trained': np.int64(3790860),
#                                   'num_env_steps_trained_lifetime': 3790860.0,
#                                   'num_env_steps_trained_lifetime_throughput': {'throughput_since_last_reduce': 23147.528432714487,
#                                                                                 'throughput_since_last_restore': 23147.527838936432},
#                                   'num_env_steps_trained_throughput': np.float64(23147.601387511884),
#                                   'num_module_steps_trained': np.int64(120704),
#                                   'num_module_steps_trained_lifetime': 120704.0,
#                                   'num_module_steps_trained_lifetime_throughput': {'throughput_since_last_reduce': 737.0354209798915,
#                                                                                    'throughput_since_last_restore': 737.0354079691177},
#                                   'num_module_steps_trained_throughput': np.float64(737.0356252459582),
#                                   'num_non_trainable_parameters': np.float64(0.0),
#                                   'num_trainable_parameters': np.float64(389895.0)},
#               'default_policy': {'curr_entropy_coeff': np.float64(0.0),
#                                  'curr_kl_coeff': np.float64(0.20000000298023224),
#                                  'default_optimizer_learning_rate': np.float64(5e-05),
#                                  'diff_num_grad_updates_vs_sampler_policy': np.float64(1.0),
#                                  'entropy': np.float64(1.7757233381271362),
#                                  'mean_kl_loss': np.float64(0.013750577345490456),
#                                  'module_train_batch_size_mean': np.float64(128.0),
#                                  'num_module_steps_trained': np.int64(120704),
#                                  'num_module_steps_trained_lifetime': 120704.0,
#                                  'num_module_steps_trained_lifetime_throughput': {'throughput_since_last_reduce': 737.0346907525854,
#                                                                                   'throughput_since_last_restore': 737.0346832818677},
#                                  'num_trainable_parameters': np.float64(389895.0),
#                                  'policy_loss': np.float64(-0.13989713788032532),
#                                  'total_loss': np.float64(9.64842700958252),
#                                  'vf_explained_var': np.float64(-0.00012123584747314453),
#                                  'vf_loss': np.float64(9.785573959350586),
#                                  'vf_loss_unclipped': np.float64(54084.80078125),
#                                  'weights_seq_no': np.float64(1.0)}},
#  'node_ip': '172.20.10.3',
#  'num_env_steps_sampled_lifetime': 4000.0,
#  'num_training_step_calls_per_iteration': 1,
#  'perf': {'cpu_util_percent': np.float64(85.72592592592594),
#           'ram_util_percent': np.float64(84.9469135802469)},
#  'pid': 10281,
#  'time_since_restore': 57.8399453163147,
#  'time_this_iter_s': 57.8399453163147,
#  'time_total_s': 57.8399453163147,
#  'timers': {'env_runner_sampling_timer': 14.478207647999625,
#             'learner_update_timer': 43.24551352599974,
#             'restore_env_runners': 5.551899994316045e-05,
#             'synch_weights': 0.07727495600011025,
#             'training_iteration': 57.81097214500005,
#             'training_step': 57.80988556400007},
#  'timestamp': 1767453461,
#  'training_iteration': 1,
#  'trial_id': 'default'}
# /home/cubic/PROJECTS/mill_copy/.venv/lib/python3.12/site-packages/ray/rllib/utils/metrics/stats/ema.py:124: RuntimeWarning: Mean of empty slice
#   return np.nanmean(self._values_to_merge)
# {'config': {'_disable_action_flattening': False,
#             '_disable_execution_plan_api': -1,
#             '_disable_initialize_loss_from_dummy_batch': False,
#             '_disable_preprocessor_api': False,
#             '_dont_auto_sync_env_runner_states': False,
#             '_enable_rl_module_api': -1,
#             '_env_to_module_connector': <function <lambda> at 0x764db0583c40>,
#             '_fake_gpus': False,
#             '_is_atari': None,
#             '_is_online': True,
#             '_learner_class': None,
#             '_learner_connector': None,
#             '_model_config': {},
#             '_module_to_env_connector': None,
#             '_per_module_overrides': {},
#             '_prior_exploration_config': {'type': 'StochasticSampling'},
#             '_rl_module_spec': None,
#             '_tf_policy_handles_more_than_one_loss': False,
#             '_torch_grad_scaler_class': None,
#             '_torch_lr_scheduler_classes': None,
#             '_train_batch_size_per_learner': None,
#             '_use_msgpack_checkpoints': False,
#             '_validate_config': True,
#             'action_mask_key': 'action_mask',
#             'action_space': None,
#             'actions_in_input_normalized': False,
#             'add_default_connectors_to_env_to_module_pipeline': True,
#             'add_default_connectors_to_learner_pipeline': True,
#             'add_default_connectors_to_module_to_env_pipeline': True,
#             'algorithm_config_overrides_per_module': {},
#             'always_attach_evaluation_results': -1,
#             'auto_wrap_old_gym_envs': -1,
#             'batch_mode': 'truncate_episodes',
#             'broadcast_env_runner_states': True,
#             'broadcast_offline_eval_runner_states': False,
#             'callbacks': <class 'ray.rllib.callbacks.callbacks.RLlibCallback'>,
#             'callbacks_on_algorithm_init': None,
#             'callbacks_on_checkpoint_loaded': None,
#             'callbacks_on_env_runners_recreated': None,
#             'callbacks_on_environment_created': None,
#             'callbacks_on_episode_created': None,
#             'callbacks_on_episode_end': None,
#             'callbacks_on_episode_start': None,
#             'callbacks_on_episode_step': None,
#             'callbacks_on_evaluate_end': None,
#             'callbacks_on_evaluate_offline_end': None,
#             'callbacks_on_evaluate_offline_start': None,
#             'callbacks_on_evaluate_start': None,
#             'callbacks_on_offline_eval_runners_recreated': None,
#             'callbacks_on_sample_end': None,
#             'callbacks_on_train_result': None,
#             'checkpoint_trainable_policies_only': False,
#             'class': <class 'ray.rllib.algorithms.ppo.ppo.PPOConfig'>,
#             'clip_actions': False,
#             'clip_param': 0.3,
#             'clip_rewards': None,
#             'compress_observations': False,
#             'count_steps_by': 'env_steps',
#             'create_env_on_driver': False,
#             'create_local_env_runner': True,
#             'custom_async_evaluation_function': -1,
#             'custom_eval_function': None,
#             'custom_resources_per_env_runner': {},
#             'custom_resources_per_offline_eval_runner': {},
#             'dataset_num_iters_per_eval_runner': 1,
#             'dataset_num_iters_per_learner': None,
#             'delay_between_env_runner_restarts_s': 60.0,
#             'disable_env_checking': False,
#             'eager_max_retraces': 20,
#             'eager_tracing': True,
#             'enable_async_evaluation': -1,
#             'enable_connectors': -1,
#             'enable_env_runner_and_connector_v2': True,
#             'enable_rl_module_and_learner': True,
#             'enable_tf1_exec_eagerly': False,
#             'entropy_coeff': 0.0,
#             'entropy_coeff_schedule': None,
#             'env': 'Taxi-v3',
#             'env_config': {},
#             'env_runner_cls': None,
#             'env_runner_health_probe_timeout_s': 30.0,
#             'env_runner_restore_timeout_s': 1800.0,
#             'env_task_fn': -1,
#             'episode_lookback_horizon': 1,
#             'episodes_to_numpy': True,
#             'evaluation_auto_duration_max_env_steps_per_sample': 2000,
#             'evaluation_auto_duration_min_env_steps_per_sample': 100,
#             'evaluation_config': None,
#             'evaluation_duration': 10,
#             'evaluation_duration_unit': 'episodes',
#             'evaluation_force_reset_envs_before_iteration': True,
#             'evaluation_interval': None,
#             'evaluation_num_env_runners': 1,
#             'evaluation_parallel_to_training': False,
#             'evaluation_sample_timeout_s': 120.0,
#             'exploration_config': {},
#             'explore': True,
#             'export_native_model_files': False,
#             'extra_python_environs_for_driver': {},
#             'extra_python_environs_for_worker': {},
#             'fake_sampler': False,
#             'framework': 'torch',
#             'gamma': 0.99,
#             'grad_clip': None,
#             'grad_clip_by': 'global_norm',
#             'gym_env_vectorize_mode': 'sync',
#             'ignore_env_runner_failures': False,
#             'ignore_final_observation': False,
#             'ignore_offline_eval_runner_failures': False,
#             'in_evaluation': False,
#             'input': 'sampler',
#             'input_compress_columns': ['obs', 'new_obs'],
#             'input_config': {},
#             'input_filesystem': None,
#             'input_filesystem_kwargs': {},
#             'input_read_batch_size': None,
#             'input_read_episodes': False,
#             'input_read_method': 'read_parquet',
#             'input_read_method_kwargs': {},
#             'input_read_sample_batches': False,
#             'input_read_schema': {},
#             'input_spaces_jsonable': True,
#             'iter_batches_kwargs': {},
#             'keep_per_episode_custom_metrics': False,
#             'kl_coeff': 0.2,
#             'kl_target': 0.01,
#             'lambda': 1.0,
#             'learner_config_dict': {},
#             'local_gpu_idx': 0,
#             'local_tf_session_args': {'inter_op_parallelism_threads': 8,
#                                       'intra_op_parallelism_threads': 8},
#             'log_gradients': False,
#             'log_level': 'WARN',
#             'log_sys_usage': True,
#             'logger_config': None,
#             'logger_creator': None,
#             'lr': 5e-05,
#             'lr_schedule': None,
#             'map_batches_kwargs': {},
#             'materialize_data': False,
#             'materialize_mapped_data': True,
#             'max_num_env_runner_restarts': 1000,
#             'max_num_offline_eval_runner_restarts': 1000,
#             'max_requests_in_flight_per_aggregator_actor': 3,
#             'max_requests_in_flight_per_env_runner': 1,
#             'max_requests_in_flight_per_learner': 3,
#             'max_requests_in_flight_per_offline_eval_runner': 1,
#             'merge_env_runner_states': 'training_only',
#             'metrics_episode_collection_timeout_s': 60.0,
#             'metrics_num_episodes_for_smoothing': 100,
#             'min_sample_timesteps_per_iteration': 0,
#             'min_time_s_per_iteration': None,
#             'min_train_timesteps_per_iteration': 0,
#             'minibatch_size': 128,
#             'model': {'_disable_action_flattening': False,
#                       '_disable_preprocessor_api': False,
#                       '_time_major': False,
#                       '_use_default_native_models': -1,
#                       'always_check_shapes': False,
#                       'attention_dim': 64,
#                       'attention_head_dim': 32,
#                       'attention_init_gru_gate_bias': 2.0,
#                       'attention_memory_inference': 50,
#                       'attention_memory_training': 50,
#                       'attention_num_heads': 1,
#                       'attention_num_transformer_units': 1,
#                       'attention_position_wise_mlp_dim': 32,
#                       'attention_use_n_prev_actions': 0,
#                       'attention_use_n_prev_rewards': 0,
#                       'conv_activation': 'relu',
#                       'conv_bias_initializer': None,
#                       'conv_bias_initializer_config': None,
#                       'conv_filters': None,
#                       'conv_kernel_initializer': None,
#                       'conv_kernel_initializer_config': None,
#                       'conv_transpose_bias_initializer': None,
#                       'conv_transpose_bias_initializer_config': None,
#                       'conv_transpose_kernel_initializer': None,
#                       'conv_transpose_kernel_initializer_config': None,
#                       'custom_action_dist': None,
#                       'custom_model': None,
#                       'custom_model_config': {},
#                       'custom_preprocessor': None,
#                       'dim': 84,
#                       'encoder_latent_dim': None,
#                       'fcnet_activation': 'tanh',
#                       'fcnet_bias_initializer': None,
#                       'fcnet_bias_initializer_config': None,
#                       'fcnet_hiddens': [256, 256],
#                       'fcnet_weights_initializer': None,
#                       'fcnet_weights_initializer_config': None,
#                       'framestack': True,
#                       'free_log_std': False,
#                       'grayscale': False,
#                       'log_std_clip_param': 20.0,
#                       'lstm_bias_initializer': None,
#                       'lstm_bias_initializer_config': None,
#                       'lstm_cell_size': 256,
#                       'lstm_use_prev_action': False,
#                       'lstm_use_prev_action_reward': -1,
#                       'lstm_use_prev_reward': False,
#                       'lstm_weights_initializer': None,
#                       'lstm_weights_initializer_config': None,
#                       'max_seq_len': 20,
#                       'no_final_linear': False,
#                       'post_fcnet_activation': 'relu',
#                       'post_fcnet_bias_initializer': None,
#                       'post_fcnet_bias_initializer_config': None,
#                       'post_fcnet_hiddens': [],
#                       'post_fcnet_weights_initializer': None,
#                       'post_fcnet_weights_initializer_config': None,
#                       'use_attention': False,
#                       'use_lstm': False,
#                       'vf_share_layers': False,
#                       'zero_mean': True},
#             'normalize_actions': True,
#             'num_aggregator_actors_per_learner': 0,
#             'num_consecutive_env_runner_failures_tolerance': 100,
#             'num_cpus_for_main_process': 1,
#             'num_cpus_per_env_runner': 1,
#             'num_cpus_per_learner': 'auto',
#             'num_cpus_per_offline_eval_runner': 1,
#             'num_env_runners': 2,
#             'num_envs_per_env_runner': 1,
#             'num_epochs': 30,
#             'num_gpus': 0,
#             'num_gpus_per_env_runner': 0,
#             'num_gpus_per_learner': 0,
#             'num_gpus_per_offline_eval_runner': 0,
#             'num_learners': 0,
#             'num_offline_eval_runners': 0,
#             'observation_filter': 'NoFilter',
#             'observation_fn': None,
#             'observation_space': None,
#             'off_policy_estimation_methods': {},
#             'offline_data_class': None,
#             'offline_eval_batch_size_per_runner': 256,
#             'offline_eval_rl_module_inference_only': False,
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
# ...
#                       'lstm_cell_size': 256,
#                       'lstm_use_prev_action': False,
#                       'lstm_use_prev_action_reward': -1,
#                       'lstm_use_prev_reward': False,
#                       'lstm_weights_initializer': None,
#                       'lstm_weights_initializer_config': None,
#                       'max_seq_len': 20,
#                       'no_final_linear': False,
#                       'post_fcnet_activation': 'relu',
#                       'post_fcnet_bias_initializer': None,
#                       'post_fcnet_bias_initializer_config': None,
#                       'post_fcnet_hiddens': [],
#                       'post_fcnet_weights_initializer': None,
#                       'post_fcnet_weights_initializer_config': None,
#                       'use_attention': False,
#                       'use_lstm': False,
#                       'vf_share_layers': False,
#                       'zero_mean': True},
#             'normalize_actions': True,
#             'num_aggregator_actors_per_learner': 0,
#             'num_consecutive_env_runner_failures_tolerance': 100,
#             'num_cpus_for_main_process': 1,
#             'num_cpus_per_env_runner': 1,
#             'num_cpus_per_learner': 'auto',
#             'num_cpus_per_offline_eval_runner': 1,
#             'num_env_runners': 2,
#             'num_envs_per_env_runner': 1,
#             'num_epochs': 30,
#             'num_gpus': 0,
#             'num_gpus_per_env_runner': 0,
#             'num_gpus_per_learner': 0,
#             'num_gpus_per_offline_eval_runner': 0,
#             'num_learners': 0,
#             'num_offline_eval_runners': 0,
#             'observation_filter': 'NoFilter',
#             'observation_fn': None,
#             'observation_space': None,
#             'off_policy_estimation_methods': {},
#             'offline_data_class': None,
#             'offline_eval_batch_size_per_runner': 256,
#             'offline_eval_rl_module_inference_only': False,
#             'offline_eval_runner_class': None,
#             'offline_eval_runner_health_probe_timeout_s': 30.0,
#             'offline_eval_runner_restore_timeout_s': 1800.0,
#             'offline_evaluation_duration': 1,
#             'offline_evaluation_interval': None,
#             'offline_evaluation_parallel_to_training': False,
#             'offline_evaluation_timeout_s': 120.0,
#             'offline_evaluation_type': None,
#             'offline_loss_for_module_fn': None,
#             'offline_sampling': False,
#             'ope_split_batch_by_episode': True,
#             'optimizer': {},
#             'output': None,
#             'output_compress_columns': ['obs', 'new_obs'],
#             'output_config': {},
#             'output_filesystem': None,
#             'output_filesystem_kwargs': {},
#             'output_max_file_size': 67108864,
#             'output_max_rows_per_file': None,
#             'output_write_episodes': True,
#             'output_write_method': 'write_parquet',
#             'output_write_method_kwargs': {},
#             'output_write_remaining_data': False,
#             'placement_strategy': 'PACK',
#             'policies': {'default_policy': (None, None, None, None)},
#             'policies_to_train': None,
#             'policy_map_cache': -1,
#             'policy_map_capacity': 100,
#             'policy_mapping_fn': <function AlgorithmConfig.DEFAULT_POLICY_MAPPING_FN at 0x764c40ecaca0>,
#             'policy_states_are_swappable': False,
#             'postprocess_inputs': False,
#             'prelearner_buffer_class': None,
#             'prelearner_buffer_kwargs': {},
#             'prelearner_class': None,
#             'prelearner_module_synch_period': 10,
#             'preprocessor_pref': 'deepmind',
#             'remote_env_batch_wait_ms': 0,
#             'remote_worker_envs': False,
#             'render_env': False,
#             'replay_sequence_length': None,
#             'restart_failed_env_runners': True,
#             'restart_failed_offline_eval_runners': True,
#             'restart_failed_sub_environments': False,
#             'rollout_fragment_length': 'auto',
#             'sample_collector': <class 'ray.rllib.evaluation.collectors.simple_list_collector.SimpleListCollector'>,
#             'sample_timeout_s': 60.0,
#             'sampler_perf_stats_ema_coef': None,
#             'seed': None,
#             'sgd_minibatch_size': -1,
#             'shuffle_batch_per_epoch': True,
#             'shuffle_buffer_size': 0,
#             'simple_optimizer': False,
#             'stats_cls_lookup': {'ema': <class 'ray.rllib.utils.metrics.stats.ema.EmaStats'>,
#                                  'item': <class 'ray.rllib.utils.metrics.stats.item.ItemStats'>,
#                                  'item_series': <class 'ray.rllib.utils.metrics.stats.item_series.ItemSeriesStats'>,
#                                  'lifetime_sum': <class 'ray.rllib.utils.metrics.stats.lifetime_sum.LifetimeSumStats'>,
#                                  'max': <class 'ray.rllib.utils.metrics.stats.max.MaxStats'>,
#                                  'mean': <class 'ray.rllib.utils.metrics.stats.mean.MeanStats'>,
#                                  'min': <class 'ray.rllib.utils.metrics.stats.min.MinStats'>,
#                                  'percentiles': <class 'ray.rllib.utils.metrics.stats.percentiles.PercentilesStats'>,
#                                  'sum': <class 'ray.rllib.utils.metrics.stats.sum.SumStats'>},
#             'sync_filters_on_rollout_workers_timeout_s': 10.0,
#             'synchronize_filters': -1,
#             'tf_session_args': {'allow_soft_placement': True,
#                                 'device_count': {'CPU': 1},
#                                 'gpu_options': {'allow_growth': True},
#                                 'inter_op_parallelism_threads': 2,
#                                 'intra_op_parallelism_threads': 2,
#                                 'log_device_placement': False},
#             'torch_compile_learner': False,
#             'torch_compile_learner_dynamo_backend': 'inductor',
#             'torch_compile_learner_dynamo_mode': None,
#             'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>,
#             'torch_compile_worker': False,
#             'torch_compile_worker_dynamo_backend': 'onnxrt',
#             'torch_compile_worker_dynamo_mode': None,
#             'torch_ddp_kwargs': {},
#             'torch_skip_nan_gradients': False,
#             'train_batch_size': 4000,
#             'update_worker_filter_stats': True,
#             'use_critic': True,
#             'use_gae': True,
#             'use_kl_loss': True,
#             'use_worker_filter_stats': True,
#             'validate_env_runners_after_construction': True,
#             'validate_offline_eval_runners_after_construction': True,
#             'vf_clip_param': 10.0,
#             'vf_loss_coeff': 1.0,
#             'vf_share_layers': -1,
#             'worker_cls': -1},
#  'date': '2026-01-03_17-20-31',
#  'done': False,
#  'env_runner_group': {'actor_manager_num_outstanding_async_reqs': 2},
#  'env_runners': {'agent_episode_return_mean': {'default_agent': np.float64(-573.5)},
#                  'env_reset_timer': np.float64(nan),
#                  'env_step_timer': np.float64(0.0002847340392106366),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.0007294341370081333),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(2.6061722299106265e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(6.352921704786471e-06),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(1.0189418143378336e-05),
#                                                                        'batch_individual_items': np.float64(7.728644202061498e-05),
#                                                                        'flatten_observations': np.float64(0.00017621813584273968),
#                                                                        'numpy_to_tensor': np.float64(0.00014960202280221268)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(113.16215454326925),
#                  'env_to_module_sum_episodes_length_out': np.float64(113.16215454326925),
#                  'episode_duration_sec_mean': np.float64(0.7361900498000296),
#                  'episode_len_max': np.int64(200),
#                  'episode_len_mean': np.float64(200.0),
#                  'episode_len_min': np.int64(200),
#                  'episode_return_max': np.float64(-497.0),
#                  'episode_return_mean': np.float64(-573.5),
#                  'episode_return_min': np.float64(-713.0),
#                  'module_episode_return_mean': {'default_policy': np.float64(-573.5)},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.0015121590658964059),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.0007081992811748375),
#                                                                        'listify_data_for_vector_env': np.float64(9.779981085408668e-05),
#                                                                        'normalize_and_clip_actions': np.float64(0.00010204308304405241),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(6.431304834482111e-06),
#                                                                        'tensor_to_numpy': np.float64(0.00020513681998244915),
#                                                                        'un_batch_to_individual_items': np.float64(5.669962815869601e-05)}}},
#                  'num_agent_steps_sampled': {'default_agent': np.int64(4000)},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 20000.0},
#                  'num_env_steps_sampled': np.int64(4000),
#                  'num_env_steps_sampled_lifetime': 20000.0,
#                  'num_env_steps_sampled_lifetime_throughput': {'throughput_since_last_reduce': 96.67966081381672,
#                                                                'throughput_since_last_restore': 59.84566615229917},
#                  'num_episodes': np.int64(20),
#                  'num_episodes_lifetime': 101.0,
#                  'num_module_steps_sampled': {'default_policy': np.int64(4000)},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 20000.0},
#                  'rlmodule_inference_timer': np.float64(0.0005347553986147589),
#                  'sample': np.float64(7.477751161000015),
#                  'time_between_sampling': np.float64(32.93011777900006),
#                  'weights_seq_no': np.float64(4.0)},
#  'fault_tolerance': {'num_healthy_workers': 2, 'num_remote_worker_restarts': 0},
#  'hostname': 'cubic',
#  'iterations_since_restore': 5,
#  'learners': {'__all_modules__': {'learner_connector': {'connector_pipeline_timer': np.float64(0.3657763769997473),
#                                                         'timers': {'connectors': {'add_columns_from_episodes_to_train_batch': np.float64(0.18701716699979443),
#                                                                                   'add_observations_from_episodes_to_batch': np.float64(0.0005547150003621937),
#                                                                                   'add_one_ts_to_episodes_and_truncate': np.float64(0.013175869999940915),
#                                                                                   'add_states_from_episodes_to_batch': np.float64(2.480100010870956e-05),
#                                                                                   'add_time_dim_to_batch_and_zero_pad': np.float64(5.206599962548353e-05),
#                                                                                   'batch_individual_items': np.float64(0.12883063500021308),
#                                                                                   'general_advantage_estimation': np.float64(0.03476120599998467),
#                                                                                   'numpy_to_tensor': np.float64(0.00038959900030022254)}}},
#                                   'learner_connector_sum_episodes_length_in': np.float64(4000.0),
#                                   'learner_connector_sum_episodes_length_out': np.float64(4022.0),
#                                   'num_env_steps_trained': np.int64(3792746),
#                                   'num_env_steps_trained_lifetime': 18962787.0,
#                                   'num_env_steps_trained_lifetime_throughput': {'throughput_since_last_reduce': 91673.16825836981,
#                                                                                 'throughput_since_last_restore': 56741.96001928472},
#                                   'num_env_steps_trained_throughput': np.float64(91673.27846357331),
#                                   'num_module_steps_trained': np.int64(120704),
#                                   'num_module_steps_trained_lifetime': 603520.0,
#                                   'num_module_steps_trained_lifetime_throughput': {'throughput_since_last_reduce': 2917.4929411965327,
#                                                                                    'throughput_since_last_restore': 1805.9002818367603},
#                                   'num_module_steps_trained_throughput': np.float64(2917.4944275687712),
#                                   'num_non_trainable_parameters': nan,
#                                   'num_trainable_parameters': nan},
#               'default_policy': {'curr_entropy_coeff': np.float64(0.0),
#                                  'curr_kl_coeff': np.float64(0.675000011920929),
#                                  'default_optimizer_learning_rate': np.float64(5e-05),
#                                  'diff_num_grad_updates_vs_sampler_policy': np.float64(1.0),
#                                  'entropy': np.float64(1.6276733875274658),
#                                  'mean_kl_loss': np.float64(0.02321450412273407),
#                                  'module_train_batch_size_mean': np.float64(128.0),
#                                  'num_module_steps_trained': np.int64(120704),
#                                  'num_module_steps_trained_lifetime': 603520.0,
#                                  'num_module_steps_trained_lifetime_throughput': {'throughput_since_last_reduce': 2917.5657500415423,
#                                                                                   'throughput_since_last_restore': 1805.8994249092755},
#                                  'num_trainable_parameters': nan,
#                                  'policy_loss': np.float64(-0.17558085918426514),
#                                  'total_loss': np.float64(9.64306354522705),
#                                  'vf_explained_var': np.float64(-0.0004146099090576172),
#                                  'vf_loss': np.float64(9.808197975158691),
#                                  'vf_loss_unclipped': np.float64(29961.935546875),
#                                  'weights_seq_no': np.float64(5.0)}},
#  'node_ip': '172.20.10.3',
#  'num_env_steps_sampled_lifetime': 20000.0,
#  'num_training_step_calls_per_iteration': 1,
#  'perf': {'cpu_util_percent': np.float64(64.01016949152543),
#           'ram_util_percent': np.float64(86.39322033898304)},
#  'pid': 10281,
#  'time_since_restore': 227.87976956367493,
#  'time_this_iter_s': 41.30037498474121,
#  'time_total_s': 227.87976956367493,
#  'timers': {'env_runner_sampling_timer': 7.589358228000037,
#             'learner_update_timer': 33.671832756000185,
#             'restore_env_runners': 1.8568000086816028e-05,
#             'synch_env_connectors': 0.006086839000090549,
#             'synch_weights': 0.013435642999866104,
#             'training_iteration': 41.281617482,
#             'training_step': 41.28115074599964},
#  'timestamp': 1767453631,
#  'training_iteration': 5,
#  'trial_id': 'default'}

# %%
# ... and evaluate it.
pprint(algo.evaluate())

# Release the algo's resources (remote actors, like EnvRunners and Learners).
algo.stop()
# Out:
# {'env_runners': {'agent_episode_return_mean': {'default_agent': np.float64(-544.7)},
#                  'env_reset_timer': np.float64(0.001462715999878128),
#                  'env_step_timer': np.float64(0.0002618527896416411),
#                  'env_to_module_connector': {'connector_pipeline_timer': np.float64(0.0006648867008215038),
#                                              'timers': {'connectors': {'add_observations_from_episodes_to_batch': np.float64(2.3753744440523946e-05),
#                                                                        'add_states_from_episodes_to_batch': np.float64(5.905644672204977e-06),
#                                                                        'add_time_dim_to_batch_and_zero_pad': np.float64(9.15015877845724e-06),
#                                                                        'batch_individual_items': np.float64(6.9489667364016e-05),
#                                                                        'flatten_observations': np.float64(0.0001578743147590486),
#                                                                        'numpy_to_tensor': np.float64(0.00013719936363182662)}}},
#                  'env_to_module_sum_episodes_length_in': np.float64(131.73765398537716),
#                  'env_to_module_sum_episodes_length_out': np.float64(131.73765398537716),
#                  'episode_duration_sec_mean': np.float64(0.6755480626999543),
#                  'episode_len_max': np.int64(200),
#                  'episode_len_mean': np.float64(200.0),
#                  'episode_len_min': np.int64(200),
#                  'episode_return_max': np.float64(-470.0),
#                  'episode_return_mean': np.float64(-544.7),
#                  'episode_return_min': np.float64(-614.0),
#                  'module_episode_return_mean': {'default_policy': np.float64(-544.7)},
#                  'module_to_env_connector': {'connector_pipeline_timer': np.float64(0.0014130602141289948),
#                                              'timers': {'connectors': {'get_actions': np.float64(0.0006616772257877382),
#                                                                        'listify_data_for_vector_env': np.float64(9.068993391511423e-05),
#                                                                        'normalize_and_clip_actions': np.float64(9.582294350439322e-05),
#                                                                        'remove_single_ts_time_rank_from_batch': np.float64(6.203059914126025e-06),
#                                                                        'tensor_to_numpy': np.float64(0.00018977086876426197),
#                                                                        'un_batch_to_individual_items': np.float64(5.271809257149952e-05)}}},
#                  'num_agent_steps_sampled': {'default_agent': np.int64(2000)},
#                  'num_agent_steps_sampled_lifetime': {'default_agent': 2000.0},
#                  'num_env_steps_sampled': np.int64(2000),
#                  'num_env_steps_sampled_lifetime': 2000.0,
#                  'num_episodes': np.int64(10),
#                  'num_episodes_lifetime': 10.0,
#                  'num_module_steps_sampled': {'default_policy': np.int64(2000)},
#                  'num_module_steps_sampled_lifetime': {'default_policy': 2000.0},
#                  'rlmodule_inference_timer': np.float64(0.0004981098882548742),
#                  'sample': np.float64(6.85297340399984),
#                  'weights_seq_no': np.float64(5.0)}}
